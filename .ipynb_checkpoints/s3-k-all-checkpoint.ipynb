# %%
# %matplotlib widget
import numpy as np
import pandas as pd
import random 
import matplotlib.pyplot as plt
import mplfinance as mpf

import tushare as ts
ts.set_token('11137efdbeac800606d677871a55b3fd5aef79890c59867a8f34d03e')
pro = ts.pro_api()

# 无复权信息
# df01 = pro.daily(ts_code = ts_code, start_date='20100101', end_date='20211231', index=0)
# df01

# %%
# read csv, add volume column, set index 
data = pd.read_csv( 's3-test.csv', index_col='Date', parse_dates=True)
# data = pd.read_csv( 's3-test.csv')
# dfcn.dropna()

data
# index_col='Date', parse_dates=Truedfcn
# dfcn.loc[:, "volume"] = df00["vol"]
# # 选择字段、调整 sort_index 顺序
# df = dfcn[['open','high','low','close','pre_close','volume', 'change', 'pct_chg', 'amount']].sort_index(ascending=True)
# df
# Out:
#                    Date     Open     High      Low    Close  Volume
# 0   2020-04-01 00:00:00  23646.0  23646.0  23622.0  23624.0      74
# 1   2020-04-01 00:01:00  23623.0  23627.0  23612.0  23627.0      68
# 2   2020-04-01 00:02:00  23626.0  23631.0  23612.0  23615.0      59
# 3   2020-04-01 00:03:00  23612.0  23625.0  23609.0  23610.0      62
# 4   2020-04-01 00:04:00  23608.0  23619.0  23604.0  23606.0      58
# 5   2020-04-01 00:05:00  23606.0  23620.0  23605.0  23620.0      50
# 6   2020-04-01 00:06:00  23621.0  23629.0  23620.0  23624.0      51
# 7   2020-04-01 00:07:00  23626.0  23644.0  23620.0  23639.0      78
# 8   2020-04-01 00:08:00  23639.0  23642.0  23631.0  23636.0      74
# 9   2020-04-01 00:09:00  23635.0  23654.0  23635.0  23651.0      72
# 10  2020-04-01 00:10:00  23654.0  23655.0  23644.0  23648.0      54
# 11  2020-04-01 00:11:00  23648.0  23652.0  23631.0  23638.0      67
# 12  2020-04-01 00:12:00  23640.0  23646.0  23638.0  23644.0      65
# ...

# %%
mpf.plot(data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
